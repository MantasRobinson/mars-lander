# %% [markdown]
# <h2>Setup</h2>

# %%
# uncomment the next line if running in a notebook
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

G = 6.67 * 10**(-11)  # gravitational constant
M = 6.42 * 10**23  # mass of Mars
R = 3396 * 10 ** 3 # radius of Mars

# %% [markdown]
# <h2>Define Euler </h2>

# %%
def Euler(g_m, g_k, g_r, g_v, g_t_max, g_dt):
    
    # mass, spring constant, initial position and velocity
    m = g_m
    k = g_k
    r = g_r
    v = g_v

    # simulation time, timestep and time
    t_max = g_t_max
    dt = g_dt
    t_array = np.arange(0, g_t_max, g_dt)

    # initialise empty lists to record trajectories
    r_list = []
    v_list = []

    # Euler integration
    for t in t_array:

        # append current state to trajectories
        r_list.append(r)
        v_list.append(v)

        # calculate new position and velocity
        a = (-(((G) * M * g_m) / (np.linalg.norm(r) ** 3)) * r) / g_m
        
        
        # Craft landing
        if abs(r[0]) < R and abs(r[1]) < R and abs(r[2]) < R:
            v = np.array([0,0,0])
        else:
            v = v + dt * a
        r = r + dt * v

    # convert trajectory lists into arrays, so they can be sliced (useful for Assignment 2)
    r_array = np.array(r_list)
    v_array = np.array(v_list)
    return r_array, v_array

# %% [markdown]
# <h2>Define Verlet</h2>

# %%
def Verlet(g_m, g_k, g_r, g_v, g_t_max, g_dt):
    
    # mass, spring constant, initial position and velocity
    # mass, spring constant, initial position and velocity
    m = g_m
    k = g_k
    r = g_r
    v = g_v

    # simulation time, timestep and time
    t_max = g_t_max
    dt = g_dt
    t_array = np.arange(0, g_t_max, g_dt)

    # initialise empty lists to record trajectories
    r_list = []
    v_list = []
    
    rplus1 = g_r + g_v * dt
    vplus1 = g_v + ((-(((G) * M * g_m) / (np.linalg.norm(r) ** 3)) * r) / g_m) * dt
    
    for t in range(1,len(t_array)):
        if not r_list:
            r_list.append(r)
            r_list.append(rplus1)
            v_list.append(v)
            v_list.append(vplus1)
            continue
        r_list.append(r)
        v_list.append(v)
        
        if abs(r[0]) < R and abs(r[1]) < R and abs(r[2]) < R:
            pass
        else:
            a = (-(((G) * M * g_m) / (np.linalg.norm(r) ** 3)) * r) / g_m
            r = (2 * r) - r_list[t-1] + ((dt**2) * a)
            v = (1 / dt) * (r - r_list[t])

    return r_list, v_list

# %% [markdown]
# <h2>Initial Tests</h2>
# <p> First test with straight down initial descent</p>

# %%
def testEstimates(g_m, g_k, g_r, g_v, g_t_max, g_dt, plotType, EulerFlag=True, VerletFlag=True):

    g_t_array = np.arange(0, g_t_max, g_dt)
    
    if EulerFlag:
        x_array, v_array = Euler(g_m, g_k, g_r, g_v, g_t_max, g_dt)
    if VerletFlag:
        vx_array, v_array = Verlet(g_m, g_k, g_r, g_v, g_t_max, g_dt)

    # plot the position-time graph
    plt.figure(1)
    plt.clf()
    plt.grid()
    labels = ["x", "y", "z"]
    plt.clf()
    plt.xlabel('time (s)')
    plt.grid()
    if plotType == "t/alt":
        plt.xlabel('time (s)')
        if EulerFlag:
            plt.plot(g_t_array, [np.linalg.norm(x) for x in x_array], label='Euler Altitude (m)')
        if VerletFlag:
            plt.plot(g_t_array, [np.linalg.norm(x) for x in vx_array], label='Verlet Altitude (m)')
    elif plotType == "x/y":
        plt.xlabel('x (m)')
        if EulerFlag:
            plt.plot([x[0] for x in x_array], [x[1] for x in x_array], label='Euler y (m)')
        if VerletFlag:
            plt.plot([x[0] for x in x_array], [x[1] for x in vx_array], label='Verlet y (m)')
    plt.legend()
    plt.show()


testEstimates(1, 1, np.array([0, (1 * 10 ** 7),0]), np.array([0,0,0]), 100000, 10, "t/alt", True, True)

# %% [markdown]
# <h3>Tests 2-4</h3>

# %%
testEstimates(1, 1, np.array([0, (1 * 10 ** 7),0]), np.array([2069,0,0]), 100000, 100, "x/y", True, True)

# %%
testEstimates(1, 1, np.array([0, (1.2 * 10 ** 7),0]), np.array([2069,0,0]), 10000000, 100, "x/y", True, True)

# %%
testEstimates(1, 1, np.array([0, (2 * 10 ** 7),0]), np.array([2069,0,0]), 10000000, 10000, "x/y", True, True)
